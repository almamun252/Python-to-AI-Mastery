# %% [markdown]
# Basic Calculation

# %%
import numpy as np

# Creating a NumPy array from a list of scores
scores = np.array([85, 92, 78, 99, 88])
print("Scores Array:", scores)

# Calculating the total sum of the scores
total = np.sum(scores)
print("Total Sum:", total) 

# Calculating the average score
average = np.mean(scores)
print("Average Score:", average)
# Out:
# Scores Array: [85 92 78 99 88]
# Total Sum: 442
# Average Score: 88.4

# %%
#          ----------------------------------          Standard deviation           -------------------------------
# In Python, standard deviation is a measure of how spread out the values in a dataset are from the mean. It is calculated using the formula:
# std = sqrt(sum((x_i - mean)^2) / n)
# where x_i represents each value in the dataset, mean is the average of the dataset, and n is the number of values in the dataset.

# Calculating the standard deviation of the scores
std_dev = np.std(scores)
print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 7.002856560004639

# %%
#          ----------------------------------          Minimum and Maximum Values           -------------------------------

lowest = np.min(scores) # Finding the minimum score
highest = np.max(scores) # Finding the maximum score

print("Lowest Score:", lowest)   
print("Highest Score:", highest)
# Out:
# Lowest Score: 78
# Highest Score: 99

# %%
#       ----------------------------------          Index of Minimum and Maximum Values           -------------------------------

# Finding the index of the minimum and maximum scores
min_index = np.argmin(scores)
max_index = np.argmax(scores)

print("Index of Lowest Score:", min_index)  
print("Index of Highest Score:", max_index)
# Out:
# Index of Lowest Score: 2
# Index of Highest Score: 3

# %%
# Working with 2D arrays (matrices) we can specify the axis along which to perform the sum.
matrix = np.array([[10, 20], 
                   [30, 40]])

print("Sum along columns (axis=0):", np.sum(matrix, axis=0)) 
print("Sum along rows (axis=1):", np.sum(matrix, axis=1))  

# Similarly, we can calculate the mean along different axes.
print("Mean along columns (axis=0):", np.mean(matrix, axis=0)) 
print("Mean along rows (axis=1):", np.mean(matrix, axis=1))

# We can also calculate the standard deviation along different axes.
print("Standard Deviation along columns (axis=0):", np.std(matrix, axis=0)) 
print("Standard Deviation along rows (axis=1):", np.std(matrix, axis=1))

# For 2D arrays, we can also find the minimum and maximum values along different axes.
print("Minimum along columns (axis=0):", np.min(matrix, axis=0)) 
print("Maximum along columns (axis=0):", np.max(matrix, axis=0))

print("Minimum along rows (axis=1):", np.min(matrix, axis=1))
print("Maximum along rows (axis=1):", np.max(matrix, axis=1))

# We can also find the indices of the minimum and maximum values along different axes.
print("Index of Minimum along columns (axis=0):", np.argmin(matrix, axis=0))
print("Index of Maximum along columns (axis=0):", np.argmax(matrix, axis=0))

print("Index of Minimum along rows (axis=1):", np.argmin(matrix, axis=1))
print("Index of Maximum along rows (axis=1):", np.argmax(matrix, axis=1))
# Out:
# Sum along columns (axis=0): [40 60]
# Sum along rows (axis=1): [30 70]
# Mean along columns (axis=0): [20. 30.]
# Mean along rows (axis=1): [15. 35.]
# Standard Deviation along columns (axis=0): [10. 10.]
# Standard Deviation along rows (axis=1): [5. 5.]
# Minimum along columns (axis=0): [10 20]
# Maximum along columns (axis=0): [30 40]
# Minimum along rows (axis=1): [10 30]
# Maximum along rows (axis=1): [20 40]
# Index of Minimum along columns (axis=0): [0 0]
# Index of Maximum along columns (axis=0): [1 1]
# Index of Minimum along rows (axis=1): [0 0]
# Index of Maximum along rows (axis=1): [1 1]

# %%
# For 3D arrays, we can specify the axis along which to perform the operations in a similar way.

arr3d = np.array([[[1, 2], [3, 4]],
                   [[5, 6], [7, 8]]])

# Sum along different axes for 3D array
print("Sum along axis=0:", np.sum(arr3d, axis=0))
print("Sum along axis=1:", np.sum(arr3d, axis=1))
print("Sum along axis=2:", np.sum(arr3d, axis=2))

# Mean along different axes for 3D array
print("Mean along axis=0:", np.mean(arr3d, axis=0))
print("Mean along axis=1:", np.mean(arr3d, axis=1))
print("Mean along axis=2:", np.mean(arr3d, axis=2))

# These ways of specifying the axis allow us to perform calculations along specific dimensions of our data,
# which is especially useful when working with multi-dimensional arrays.
# Out:
# Sum along axis=0: [[ 6  8]
#  [10 12]]
# Sum along axis=1: [[ 4  6]
#  [12 14]]
# Sum along axis=2: [[ 3  7]
#  [11 15]]
# Mean along axis=0: [[3. 4.]
#  [5. 6.]]
# Mean along axis=1: [[2. 3.]
#  [6. 7.]]
# Mean along axis=2: [[1.5 3.5]
#  [5.5 7.5]]

# %% [markdown]
# Conditions & Searching

# %%
# -------------------------------          Conditional Assignment with np.where           -------------------------------

scores = np.array([45, 88, 92, 30, 78])

# This works much like running an if-else condition inside an array.
# Its syntax is: np.where(condition, what to do if condition is true, what to do if condition is false).

status = np.where(scores > 80, 'Accepted', 'Review') # Conditionally assigning 'Accepted' if score is greater than 80, otherwise 'Review'
print("Status:", status)
# Out:
# Status: ['Review' 'Accepted' 'Accepted' 'Review' 'Review']

# %%
#  -------------------------------          Handling Missing Values with np.isnan()           -------------------------------

# a data set with missing values (np.nan)
sensor_data = np.array([12.5, np.nan, 14.1, np.nan, 15.0])

# checking where the NaN values are (this returns True/False)
missing_check = np.isnan(sensor_data)
print("Missing Values Check:", missing_check)


# checking how many missing values there are
total_missing = np.sum(np.isnan(sensor_data))
print("Total Missing Values:", total_missing) 

# Replacing NaN values with the mean of the non-missing values
mean_value = np.nanmean(sensor_data) # np.nanmean() calculates the mean while ignoring NaN values
print("Mean Value (Ignoring NaN):", mean_value)

# Replacing NaN with the mean value
filled_sensor_data = np.where(np.isnan(sensor_data), mean_value, sensor_data) 
print("Sensor Data with NaN Replaced:", filled_sensor_data)
# Out:
# Missing Values Check: [False  True False  True False]
# Total Missing Values: 2
# Mean Value (Ignoring NaN): 13.866666666666667
# Sensor Data with NaN Replaced: [12.5        13.86666667 14.1        13.86666667 15.        ]

# %%
# -------------------------------          Finding Unique Classes in Predictions           -------------------------------

# Suppose we have some predicted class names from a model
predictions = np.array(['Class_A', 'Class_B', 'Class_A', 'Class_C', 'Class_B'])

# Finding the unique classes and their counts
unique_classes,counts = np.unique(predictions, return_counts=True) 
print("Unique Classes:", unique_classes)
print("Counts of Each Class:", counts)

# We can also find the indices of the unique classes in the original array
unique_indices = np.unique(predictions, return_index=True)[1]
print("Indices of Unique Classes:", unique_indices)
# Out:
# Unique Classes: ['Class_A' 'Class_B' 'Class_C']
# Counts of Each Class: [2 2 1]
# Indices of Unique Classes: [0 1 3]

# %%
#  -------------------------------          Clipping Values with np.clip()           -------------------------------

# let's say we have some gradient values that we want to clip to a certain range
gradients = np.array([-5.0, -0.5, 0.8, 3.5, 10.0])

# This will set any value less than -1 to -1, and any value greater than 1 to 1
clipped_grads = np.clip(gradients, -1.0, 1.0) 

print("Original Gradients:", gradients)
print("Clipped Gradients:", clipped_grads)
# Out:
# Original Gradients: [-5.  -0.5  0.8  3.5 10. ]
# Clipped Gradients: [-1.  -0.5  0.8  1.   1. ]
